# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('employee_data.csv')

print("Original Dataset")
print(df)

# Handle missing values
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df['Name'] = df['Name'].fillna('Unknown')

# Remove duplicates
df = df.drop_duplicates()

print("\nCleaned Dataset")
print(df)

# Generate summary report
report = df.describe()

print("\nSummary Report")
print(report)

# Department-wise average salary
dept_salary = df.groupby('Department')['Salary'].mean()

print("\nDepartment Wise Average Salary")
print(dept_salary)

# Visualization
plt.figure(figsize=(6,4))
dept_salary.plot(kind='bar')

plt.title('Average Salary by Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.grid(True)

plt.show()

# Save cleaned dataset
df.to_csv('cleaned_employee_data.csv', index=False)

# Save report
report.to_csv('summary_report.csv')
# Out:
# Original Dataset
#    EmployeeID     Name Department   Salary
# 0         101     John         HR  50000.0
# 1         102    Alice         IT  60000.0
# 2         103      Bob    Finance      NaN
# 3         104     John         HR  50000.0
# 4         105     Emma         IT  65000.0
# 5         106      NaN    Finance  55000.0
# 6         107    David         IT  62000.0
# 7         108   Sophia         HR      NaN
# 8         109  Michael    Finance  58000.0
# 9         110     Emma         IT  65000.0
#
# Cleaned Dataset
#    EmployeeID     Name Department   Salary
# 0         101     John         HR  50000.0
# 1         102    Alice         IT  60000.0
# 2         103      Bob    Finance  58125.0
# 3         104     John         HR  50000.0
# 4         105     Emma         IT  65000.0
# 5         106  Unknown    Finance  55000.0
# 6         107    David         IT  62000.0
# 7         108   Sophia         HR  58125.0
# 8         109  Michael    Finance  58000.0
# 9         110     Emma         IT  65000.0
#
# Summary Report
#        EmployeeID       Salary
# count    10.00000     10.00000
# mean    105.50000  58125.00000
# std       3.02765   5321.60168
# min     101.00000  50000.00000
# 25%     103.25000  55750.00000
# 50%     105.50000  58125.00000
# 75%     107.75000  61500.00000
# max     110.00000  65000.00000
#
# Department Wise Average Salary
# Department
# Finance    57041.666667
# HR         52708.333333
# IT         63000.000000
# Name: Salary, dtype: float64
